# %% [markdown]
# # Horizontal pressure gradient errors due to the ice shelf  #
#
# In ALE mode and when the ice shelf is included, spurios velocities due to horizontal pressure gradient errors arise underneath the ice shelf:

# %%
from IPython.display import Image
Image('figures/fig_05.png') # ALE Z* in 2D

# %%
Image('figures/fig_06.png')

# %% [markdown]
# The velocities grow to ~ 8e-4 m/s and affect the entire domain.

# %%
Image('figures/fig_07.png')

# %%
# this problem is much worse in 3D
Image('figures/fig_08.png')

# %%
# at y = 1 km
# note the issue at the ice shelf front.
Image('figures/fig_09.png')

# %%
Image('figures/fig_10.png')

# %% [markdown]
# The results are worse in sigma and rho modes, see [this notebook](https://github.com/gustavo-marques/ISOMIP/blob/master/ipynb/quiet_2D_yesIS.ipynb).
