# %% [markdown]
# # Inconsistency in ALE sponge layers #
#
# I did a test using ALE z* where I applied a sponge layer using the same T/S values used in the interior. I expected that the T/S profiles would look indentical inside and outside the sponge layer. However, for a fixed layer, the salinity (therefore density) values inside and outside the sponge layer are not the same:

# %%
from IPython.display import Image
Image('figures/fig_11.png') # ALE Z* in 2D

# %% [markdown]
# This inconsistency generates untanted velocities:

# %%
Image('figures/fig_12.png')
