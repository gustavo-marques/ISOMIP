# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../plotting/')
from plotting import *
import netCDF4
import numpy as np

# %%
# plot IC
path='/lustre/f1/unswept/Gustavo.Marques/MOM6-examples/ocean_only/ISOMIP/TESTS/3D/NO_IS/'
icfile = 'ISOMIP_IC.nc'
layer_file = netCDF4.Dataset(path+'layer/'+icfile)
rho_file = netCDF4.Dataset(path+'rho/'+icfile)
sigma_file = netCDF4.Dataset(path+'sigma/'+icfile)
z_file = netCDF4.Dataset(path+'z/'+icfile)
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['latq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate
record = 0
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=20, variable='Salt', eta='eta'); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=20, variable='Salt', eta='eta'); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=20, variable='Salt', eta='eta'); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=20, variable='Salt', eta='eta'); plt.title(r'z*', fontsize=18);
plt.tight_layout()

# %%
# Open the output from the four experiments
prog_file='prog__0001_002.nc'
layer_file = netCDF4.Dataset(path+'layer/'+prog_file)
rho_file = netCDF4.Dataset(path+'rho/'+prog_file)
sigma_file = netCDF4.Dataset(path+'sigma/'+prog_file)
z_file = netCDF4.Dataset(path+'z/'+prog_file)

# %%
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['yq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate

# %%
record = 9 
print 'Time is:',layer_file.variables['Time'][record], 'days'
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=20); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=20); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=20); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=20); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# Time is: 10.0 days

# %%
variable = 'u'
print ('u @ j=20')
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=20, variable=variable, clim=(-1e-10,1e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=20, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=20, variable=variable, clim=(-1e-3,1e-3)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=20, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# u @ j=20

# %%
variable = 'u'
print ('u @ j=1')
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=1, variable=variable, clim=(-1e-10,1e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=1, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=1, variable=variable, clim=(-1e-3,1e-3)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=1, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# u @ j=1

# %%
variable = 'v'
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=20, variable=variable, clim=(-2e-10,2e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=20, variable=variable, clim=(-2e-4,2e-4)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=20, variable=variable, clim=(-2e-3,2e-3)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=20, variable=variable, clim=(-2e-3,2e-3)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
record=-1
print 'Time is:',layer_file.variables['Time'][record], 'days'
variable = 'u'
print ('u @ j=20')
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=20, variable=variable, clim=(-1e-10,1e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=20, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=20, variable=variable, clim=(-1e-3,1e-3)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=20, variable=variable, clim=(-1e-4,1e-4)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# Time is: 365.0 days
# u @ j=20

# %%
print ('u @ j=1')
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=1, variable=variable, clim=(-1e-10,1e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=1, variable=variable, clim=(-1e-10,1e-10)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=1, variable=variable, clim=(-1e-3,1e-3)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=1, variable=variable, clim=(-1e-4,1e-4)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# u @ j=1

# %%
plot_stats((layer_file,rho_file,sigma_file,z_file))
