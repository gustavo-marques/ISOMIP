# %% [markdown]
# # Cold forcing
# This test should not generate any motion since T/S values identical to the IC are applied in the sponge layer.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../plotting/')
from plotting import *
import netCDF4
import numpy as np

# %%
# plot IC
path='/lustre/f1/unswept/Gustavo.Marques/MOM6-examples/ocean_only/ISOMIP/TESTS/2D/SPONGES/COLD/'
icfile = 'ISOMIP_IC.nc'
layer_file = netCDF4.Dataset(path+'layer/'+icfile)
rho_file = netCDF4.Dataset(path+'rho/'+icfile)
sigma_file = netCDF4.Dataset(path+'sigma/'+icfile)
z_file = netCDF4.Dataset(path+'z/'+icfile)
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['lonq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate
record = 0
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, variable='Salt', eta='eta'); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, variable='Salt', eta='eta'); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, variable='Salt', eta='eta'); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, variable='Salt', eta='eta'); plt.title(r'z*', fontsize=18);
plt.tight_layout()

# %%
# Open the output from the four experiments
prog_file='prog__0001_002.nc'
layer_file = netCDF4.Dataset(path+'layer/'+prog_file)
rho_file = netCDF4.Dataset(path+'rho/'+prog_file)
sigma_file = netCDF4.Dataset(path+'sigma/'+prog_file)
z_file = netCDF4.Dataset(path+'z/'+prog_file)

# %%
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['xq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate

# %%
record = 9
print 'Time is:',layer_file.variables['Time'][record], 'days'
xlim=(700,800)
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, xlim=xlim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, xlim=xlim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, xlim=xlim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, xlim=xlim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
# Time is: 10.0 days

# %%
variable = 'rhoinsitu'
clim=(1027.16,1027.9)
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, variable=variable, xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, variable=variable, xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, variable=variable, xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, variable=variable, xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
variable = 'u'
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, variable=variable, clim=(-2e-5,2e-5)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
variable = 'v'
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, variable=variable, clim=(-2e-5,2e-5)); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, variable=variable, clim=(-2e-10,2e-10)); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
plot_stats((layer_file,rho_file,sigma_file,z_file))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-8d38fda959d4> in <module>()
# ----> 1 plot_stats((layer_file,rho_file,sigma_file,z_file))
#
# /autofs/mnt/ncrc-svm1_home2/Gustavo.Marques/Notebooks/ISOMIP/plotting/plotting.py in plot_stats(file_handle, variable, labels)
#      47         s = file_handle[i].variables[variable][:]
#      48         for t in range(len(time)):
# ---> 49             smin[t]=s[t,:].min(); smax[t]=s[t,:].max()
#      50
#      51         ax[0].plot(time,smin,lw=2.0, label=labels[i])
#
# /ncrc/home2/Gustavo.Marques/anaconda2/lib/python2.7/site-packages/numpy/ma/core.pyc in __getitem__(self, indx)
#    3113
#    3114         """
# -> 3115         dout = self.data[indx]
#    3116         # We could directly use ndarray.__getitem__ on self.
#    3117         # But then we would have to modify __array_finalize__ to prevent the
#
# ...
