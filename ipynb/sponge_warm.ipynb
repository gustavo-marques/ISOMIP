# %% [markdown]
# # Warm forcing
# T/S values in hte sponge are different than the IC, but rho should be the same.This test should generate some motion due to the diffusion of tracers next to the sponge layer.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../plotting/')
from plotting import *
import netCDF4
import numpy as np

# %%
# plot IC
path='/lustre/f1/unswept/Gustavo.Marques/MOM6-examples/ocean_only/ISOMIP/TESTS/2D/SPONGES/WARM/'
icfile = 'ISOMIP_IC.nc'
layer_file = netCDF4.Dataset(path+'layer/'+icfile)
rho_file = netCDF4.Dataset(path+'rho/'+icfile)
sigma_file = netCDF4.Dataset(path+'sigma/'+icfile)
z_file = netCDF4.Dataset(path+'z/'+icfile)
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['latq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate
record = 0
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=2,variable='Salt', eta='eta'); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable='Salt', eta='eta'); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=2,variable='Salt', eta='eta'); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=2,variable='Salt', eta='eta'); plt.title(r'z*', fontsize=18);
plt.tight_layout()

# %%
# Open the output from the four experiments
prog_file='prog__0001_002.nc'
layer_file = netCDF4.Dataset(path+'layer/'+prog_file)
rho_file = netCDF4.Dataset(path+'rho/'+prog_file)
sigma_file = netCDF4.Dataset(path+'sigma/'+prog_file)
z_file = netCDF4.Dataset(path+'z/'+prog_file)

# %%
# Read the horizontal coordinate which is the same for all configurations 
xq = layer_file.variables['yq'][:] # This is the coordinate of the cell corners (u-points in 1D)
xq = np.concatenate(([0],xq)) # Inserts left most edge of domain in to coordinate

# %%
record = 364
print 'Time is:',layer_file.variables['Time'][record], 'days'
xlim=(700,800)
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=2,xlim=xlim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq, i=2,xlim=xlim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, xlim=xlim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=2,xlim=xlim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
# Out:
#  Time is: 365.0 days

# %%
variable = 'rhoinsitu'
clim=(1027.16,1027.9)
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
variable = 'temp'
clim=(-1.9,1.0)
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq, i=2,variable=variable, xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq,i=2, variable=variable, xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
record = 9
variable = 'u'
clim=(-1e-2,1e-2)
xlim=(320,800)
record = 0
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq, i=2,variable=variable,xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq, i=2,variable=variable,xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
record = 9
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
variable = 'v'
clim=(-1e-2,1e-2)
xlim=(320,800)
record = 0
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()
record = 9
plt.figure(figsize=(18,9))
plt.subplot(2,2,1); plot_section(layer_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title('Layer', fontsize=18);
plt.subplot(2,2,2); plot_section(rho_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\rho$', fontsize=18);
plt.subplot(2,2,3); plot_section(sigma_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$\sigma$', fontsize=18);
plt.subplot(2,2,4); plot_section(z_file, record, xq,i=2, variable=variable,xlim=xlim, clim=clim); plt.title(r'$z^*$', fontsize=18);
plt.tight_layout()

# %%
plot_stats((layer_file,rho_file,sigma_file,z_file))
