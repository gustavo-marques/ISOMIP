# %% [markdown]
# # Spurious velocities in “quiet experiments”  #
#
# Quite experiment is when the model is run with the prescribed stratification and without any forcing (and no ice shelf). When using ALE Z* mode, spurious velocities are generated in a specific location of the domain (x ~ 450 km).
#
# PS: with rho mode this does not happen and, <b>with sigma, spurious velocities are even worse</b>, but for a different reason. Check [this notebook](https://github.com/gustavo-marques/ISOMIP/blob/master
# /ipynb/quiet_3D_noIS.ipynb).

# %%
from IPython.display import Image
Image('figures/fig_01.png') # ALE Z*

# %%
Image('figures/fig_02.png')

# %%
Image('figures/fig_03.png')

# %% [markdown]
# This problem does not occur in 2D:

# %%
Image('figures/fig_04.png') # 2D Ale z*

# %% [markdown]
# It also does not occur In 3D when the “bump” in the continental shelf is removed (not shown). The problem is wrose in sigma and it does not occur in rho or layer. See [this notebook](https://github.com/gustavo-marques/ISOMIP/blob/master/ipynb/quiet_3D_noIS.ipynb) for additional information.
